# %% [markdown]
# # The Daily

# %%
# Daily Imports
import daily
chrome = daily.Chrome()
instagram = daily.Instagram()
pinterest = daily.Pinterest(['Travel'])
pocket = daily.Pocket()
quotes = daily.Quotes('https://www.goodreads.com/author/quotes/2622245.Lao_Tzu', 'Lao Tzu')
reddit = daily.Reddit(['tifu'])
tasks = daily.Tasks()

# %% [markdown]
# ## Chrome Bookmarks

# %%
chrome.get_bookmarks()

# %% [markdown]
# ## Instagram Feed Posts

# %%
instagram.get_posts()

# %% [markdown]
# ## Pinterest Reccomendations

# %%
pinterest.get_pins()

# %% [markdown]
# ## Pocket Items

# %%
pocket.get_items()

# %% [markdown]
# ## Daily Quote

# %%
quotes.get_quotes()

# %% [markdown]
# ## Reddit Posts

# %%
reddit.get_posts()

# %% [markdown]
# ## Google Tasks

# %%
tasks.get_tasks()
